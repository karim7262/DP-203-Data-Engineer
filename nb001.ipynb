# %%
#Variable Declaration with default values...Require to change
storage_account_name="sa14mujahed"
storage_account_key="iF8iteS5WYJMJqRmBE2XhJxCCVnNC061BO4exNbzglRfRJ9vZOEtsCuvNHa7THt0tt6aI1RIoNNCY/QL/C48kQ=="
container="container"

KEY="fs.azure.account.key.{0}.blob.core.windows.net".format(storage_account_name)
VALUE=storage_account_key

#Configure Spark at runtime
spark.conf.set(KEY,VALUE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Mount from Azure Blob Storage to DBFS
source_url="wasbs://{0}@{1}.blob.core.windows.net".format(container,storage_account_name)
mntURL="/mnt/azurestorage01"
blnResult=dbutils.fs.mount(source=source_url,mount_point=mntURL,extra_configs={ KEY:VALUE })
if blnResult==True:
  print("Mounted Successfully...")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#To check mount point
dbutils.fs.ls("dbfs:"+mntURL)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Read data from mount point and create df object
df=spark.read.text(mntURL+"/1000_Sales_Records.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
output_url=mntURL+"/output_sales1.csv"
df.write.option("header","true").format("com.databricks.spark.csv").save(output_url)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dbutils.fs.ls(mntURL)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dbutils.fs.unmount(mntURL)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
